# %%
import pandas as pd
import numpy as np

# %%
path = 'https://frenzy86.s3.eu-west-2.amazonaws.com/python/data/life.csv'
df = pd.read_csv(path)
df
# Out:
#                                 Country  Year  Adult Mortality  infant deaths  \
# 0                           Afghanistan  2015            263.0             62
# 1                               Albania  2015             74.0              0
# 2                               Algeria  2015             19.0             21
# 3                                Angola  2015            335.0             66
# 4                   Antigua and Barbuda  2015             13.0              0
# ..                                  ...   ...              ...            ...
# 178  Venezuela (Bolivarian Republic of)  2015            157.0              9
# 179                            Viet Nam  2015            127.0             28
# 180                               Yemen  2015            224.0             37
# 181                              Zambia  2015             33.0             27
# 182                            Zimbabwe  2015            336.0             22
#
#      percentage expenditure  Hepatitis B  Measles    BMI   under-five deaths   \
# 0                 71.279624         65.0      1154   19.1                  83
# 1                364.975229         99.0         0   58.0                   0
# 2                  0.000000         95.0        63   59.5                  24
# 3                  0.000000         64.0       118   23.3                  98
# 4                  0.000000         99.0         0   47.7                   0
# ..                      ...          ...       ...    ...                 ...
# 178                0.000000         87.0         0   62.1                  10
# 179                0.000000         97.0       256   17.5                  35
# 180                0.000000         69.0       468   41.3                  47
# 181                0.000000          9.0         9   23.4                  40
# 182                0.000000         87.0         0   31.8                  32
#
#      Polio  Diphtheria    HIV/AIDS   thinness  1-19 years  \
# 0      6.0         65.0        0.1                   17.2
# 1     99.0         99.0        0.1                    1.2
# 2     95.0         95.0        0.1                    6.0
# 3      7.0         64.0        1.9                    8.3
# 4     86.0         99.0        0.2                    3.3
# ..     ...          ...        ...                    ...
# 178   87.0         87.0        0.1                    1.6
# 179   97.0         97.0        0.1                   14.2
# 180   63.0         69.0        0.1                   13.6
# 181    9.0          9.0        4.1                    6.3
# 182   88.0         87.0        6.2                    5.6
#
#       thinness 5-9 years  Income composition of resources  Schooling  Life_exp
# 0                   17.3                            0.479       10.1      65.0
# 1                    1.3                            0.762       14.2      77.8
# 2                    5.8                            0.743       14.4      75.6
# 3                    8.2                            0.531       11.4      52.4
# 4                    3.3                            0.784       13.9      76.4
# ..                   ...                              ...        ...       ...
# 178                  1.5                            0.769       14.3      74.1
# 179                 14.5                            0.678       12.6      76.0
# 180                 13.4                            0.499        9.0      65.7
# 181                  6.1                            0.576       12.5      61.8
# 182                  5.5                            0.507       10.3      67.0
#
# [183 rows x 17 columns]

# %%
df.head()
# Out:
#                Country  Year  Adult Mortality  infant deaths  \
# 0          Afghanistan  2015            263.0             62
# 1              Albania  2015             74.0              0
# 2              Algeria  2015             19.0             21
# 3               Angola  2015            335.0             66
# 4  Antigua and Barbuda  2015             13.0              0
#
#    percentage expenditure  Hepatitis B  Measles    BMI   under-five deaths   \
# 0               71.279624         65.0      1154   19.1                  83
# 1              364.975229         99.0         0   58.0                   0
# 2                0.000000         95.0        63   59.5                  24
# 3                0.000000         64.0       118   23.3                  98
# 4                0.000000         99.0         0   47.7                   0
#
#    Polio  Diphtheria    HIV/AIDS   thinness  1-19 years   thinness 5-9 years  \
# 0    6.0         65.0        0.1                   17.2                 17.3
# 1   99.0         99.0        0.1                    1.2                  1.3
# 2   95.0         95.0        0.1                    6.0                  5.8
# 3    7.0         64.0        1.9                    8.3                  8.2
# 4   86.0         99.0        0.2                    3.3                  3.3
#
#    Income composition of resources  Schooling  Life_exp
# 0                            0.479       10.1      65.0
# 1                            0.762       14.2      77.8
# 2                            0.743       14.4      75.6
# 3                            0.531       11.4      52.4
# 4                            0.784       13.9      76.4

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 183 entries, 0 to 182
# Data columns (total 17 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          183 non-null    object
#  1   Year                             183 non-null    int64
#  2   Adult Mortality                  183 non-null    float64
#  3   infant deaths                    183 non-null    int64
#  4   percentage expenditure           183 non-null    float64
#  5   Hepatitis B                      183 non-null    float64
#  6   Measles                          183 non-null    int64
#  7    BMI                             183 non-null    float64
#  8   under-five deaths                183 non-null    int64
#  9   Polio                            183 non-null    float64
#  10  Diphtheria                       183 non-null    float64
#  11   HIV/AIDS                        183 non-null    float64
#  12   thinness  1-19 years            183 non-null    float64
#  13   thinness 5-9 years              183 non-null    float64
#  14  Income composition of resources  183 non-null    float64
#  15  Schooling                        183 non-null    float64
#  16  Life_exp                         183 non-null    float64
# dtypes: float64(12), int64(4), object(1)
# memory usage: 24.4+ KB

# %%
df.drop('Year', axis=1, inplace=True)
df
# Out:
#                                 Country  Adult Mortality  infant deaths  \
# 0                           Afghanistan            263.0             62
# 1                               Albania             74.0              0
# 2                               Algeria             19.0             21
# 3                                Angola            335.0             66
# 4                   Antigua and Barbuda             13.0              0
# ..                                  ...              ...            ...
# 178  Venezuela (Bolivarian Republic of)            157.0              9
# 179                            Viet Nam            127.0             28
# 180                               Yemen            224.0             37
# 181                              Zambia             33.0             27
# 182                            Zimbabwe            336.0             22
#
#      percentage expenditure  Hepatitis B  Measles    BMI   under-five deaths   \
# 0                 71.279624         65.0      1154   19.1                  83
# 1                364.975229         99.0         0   58.0                   0
# 2                  0.000000         95.0        63   59.5                  24
# 3                  0.000000         64.0       118   23.3                  98
# 4                  0.000000         99.0         0   47.7                   0
# ..                      ...          ...       ...    ...                 ...
# 178                0.000000         87.0         0   62.1                  10
# 179                0.000000         97.0       256   17.5                  35
# 180                0.000000         69.0       468   41.3                  47
# 181                0.000000          9.0         9   23.4                  40
# 182                0.000000         87.0         0   31.8                  32
#
#      Polio  Diphtheria    HIV/AIDS   thinness  1-19 years  \
# 0      6.0         65.0        0.1                   17.2
# 1     99.0         99.0        0.1                    1.2
# 2     95.0         95.0        0.1                    6.0
# 3      7.0         64.0        1.9                    8.3
# 4     86.0         99.0        0.2                    3.3
# ..     ...          ...        ...                    ...
# 178   87.0         87.0        0.1                    1.6
# 179   97.0         97.0        0.1                   14.2
# 180   63.0         69.0        0.1                   13.6
# 181    9.0          9.0        4.1                    6.3
# 182   88.0         87.0        6.2                    5.6
#
#       thinness 5-9 years  Income composition of resources  Schooling  Life_exp
# 0                   17.3                            0.479       10.1      65.0
# 1                    1.3                            0.762       14.2      77.8
# 2                    5.8                            0.743       14.4      75.6
# 3                    8.2                            0.531       11.4      52.4
# 4                    3.3                            0.784       13.9      76.4
# ..                   ...                              ...        ...       ...
# 178                  1.5                            0.769       14.3      74.1
# 179                 14.5                            0.678       12.6      76.0
# 180                 13.4                            0.499        9.0      65.7
# 181                  6.1                            0.576       12.5      61.8
# 182                  5.5                            0.507       10.3      67.0
#
# [183 rows x 16 columns]

# %%
df.drop('Country',axis=1, inplace=True)
df
# Out:
#      Adult Mortality  infant deaths  percentage expenditure  Hepatitis B  \
# 0              263.0             62               71.279624         65.0
# 1               74.0              0              364.975229         99.0
# 2               19.0             21                0.000000         95.0
# 3              335.0             66                0.000000         64.0
# 4               13.0              0                0.000000         99.0
# ..               ...            ...                     ...          ...
# 178            157.0              9                0.000000         87.0
# 179            127.0             28                0.000000         97.0
# 180            224.0             37                0.000000         69.0
# 181             33.0             27                0.000000          9.0
# 182            336.0             22                0.000000         87.0
#
#      Measles    BMI   under-five deaths   Polio  Diphtheria    HIV/AIDS  \
# 0        1154   19.1                  83    6.0         65.0        0.1
# 1           0   58.0                   0   99.0         99.0        0.1
# 2          63   59.5                  24   95.0         95.0        0.1
# 3         118   23.3                  98    7.0         64.0        1.9
# 4           0   47.7                   0   86.0         99.0        0.2
# ..        ...    ...                 ...    ...          ...        ...
# 178         0   62.1                  10   87.0         87.0        0.1
# 179       256   17.5                  35   97.0         97.0        0.1
# 180       468   41.3                  47   63.0         69.0        0.1
# 181         9   23.4                  40    9.0          9.0        4.1
# 182         0   31.8                  32   88.0         87.0        6.2
#
#       thinness  1-19 years   thinness 5-9 years  \
# 0                     17.2                 17.3
# 1                      1.2                  1.3
# 2                      6.0                  5.8
# 3                      8.3                  8.2
# 4                      3.3                  3.3
# ..                     ...                  ...
# 178                    1.6                  1.5
# 179                   14.2                 14.5
# 180                   13.6                 13.4
# 181                    6.3                  6.1
# 182                    5.6                  5.5
#
#      Income composition of resources  Schooling  Life_exp
# 0                              0.479       10.1      65.0
# 1                              0.762       14.2      77.8
# 2                              0.743       14.4      75.6
# 3                              0.531       11.4      52.4
# 4                              0.784       13.9      76.4
# ..                               ...        ...       ...
# 178                            0.769       14.3      74.1
# 179                            0.678       12.6      76.0
# 180                            0.499        9.0      65.7
# 181                            0.576       12.5      61.8
# 182                            0.507       10.3      67.0
#
# [183 rows x 15 columns]

# %%
df.drop('percentage expenditure', axis=1, inplace=True)
df
# Out:
#      Adult Mortality  infant deaths  Hepatitis B  Measles    BMI   \
# 0              263.0             62         65.0      1154   19.1
# 1               74.0              0         99.0         0   58.0
# 2               19.0             21         95.0        63   59.5
# 3              335.0             66         64.0       118   23.3
# 4               13.0              0         99.0         0   47.7
# ..               ...            ...          ...       ...    ...
# 178            157.0              9         87.0         0   62.1
# 179            127.0             28         97.0       256   17.5
# 180            224.0             37         69.0       468   41.3
# 181             33.0             27          9.0         9   23.4
# 182            336.0             22         87.0         0   31.8
#
#      under-five deaths   Polio  Diphtheria    HIV/AIDS   thinness  1-19 years  \
# 0                    83    6.0         65.0        0.1                   17.2
# 1                     0   99.0         99.0        0.1                    1.2
# 2                    24   95.0         95.0        0.1                    6.0
# 3                    98    7.0         64.0        1.9                    8.3
# 4                     0   86.0         99.0        0.2                    3.3
# ..                  ...    ...          ...        ...                    ...
# 178                  10   87.0         87.0        0.1                    1.6
# 179                  35   97.0         97.0        0.1                   14.2
# 180                  47   63.0         69.0        0.1                   13.6
# 181                  40    9.0          9.0        4.1                    6.3
# 182                  32   88.0         87.0        6.2                    5.6
#
#       thinness 5-9 years  Income composition of resources  Schooling  Life_exp
# 0                   17.3                            0.479       10.1      65.0
# 1                    1.3                            0.762       14.2      77.8
# 2                    5.8                            0.743       14.4      75.6
# 3                    8.2                            0.531       11.4      52.4
# 4                    3.3                            0.784       13.9      76.4
# ..                   ...                              ...        ...       ...
# 178                  1.5                            0.769       14.3      74.1
# 179                 14.5                            0.678       12.6      76.0
# 180                 13.4                            0.499        9.0      65.7
# 181                  6.1                            0.576       12.5      61.8
# 182                  5.5                            0.507       10.3      67.0
#
# [183 rows x 14 columns]

# %%
df.tail()
# Out:
#      Adult Mortality  infant deaths  Hepatitis B  Measles    BMI   \
# 178            157.0              9         87.0         0   62.1
# 179            127.0             28         97.0       256   17.5
# 180            224.0             37         69.0       468   41.3
# 181             33.0             27          9.0         9   23.4
# 182            336.0             22         87.0         0   31.8
#
#      under-five deaths   Polio  Diphtheria    HIV/AIDS   thinness  1-19 years  \
# 178                  10   87.0         87.0        0.1                    1.6
# 179                  35   97.0         97.0        0.1                   14.2
# 180                  47   63.0         69.0        0.1                   13.6
# 181                  40    9.0          9.0        4.1                    6.3
# 182                  32   88.0         87.0        6.2                    5.6
#
#       thinness 5-9 years  Income composition of resources  Schooling  Life_exp
# 178                  1.5                            0.769       14.3      74.1
# 179                 14.5                            0.678       12.6      76.0
# 180                 13.4                            0.499        9.0      65.7
# 181                  6.1                            0.576       12.5      61.8
# 182                  5.5                            0.507       10.3      67.0

# %%
df.isnull().sum()
# Out:
# Adult Mortality                    0
# infant deaths                      0
# Hepatitis B                        0
# Measles                            0
#  BMI                               0
# under-five deaths                  0
# Polio                              0
# Diphtheria                         0
#  HIV/AIDS                          0
#  thinness  1-19 years              0
#  thinness 5-9 years                0
# Income composition of resources    0
# Schooling                          0
# Life_exp                           0
# dtype: int64

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# Adult Mortality                    0
# infant deaths                      0
# Hepatitis B                        0
# Measles                            0
#  BMI                               0
# under-five deaths                  0
# Polio                              0
# Diphtheria                         0
#  HIV/AIDS                          0
#  thinness  1-19 years              0
#  thinness 5-9 years                0
# Income composition of resources    0
# Schooling                          0
# Life_exp                           0
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

# %%
X = df.drop(columns='Life_exp')
y = df['Life_exp']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    test_size=0.2, 
                                                    random_state=667)

# %%
model = LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([-2.98104327e-02,  8.69153644e-02,  2.75531888e-02, -4.25947075e-05,
#         1.38515742e-02, -6.39754943e-02,  1.38793079e-02,  1.09043445e-02,
#        -4.31597801e-01, -2.86336016e-01,  3.41159404e-03,  2.41430940e+01,
#        -2.57118503e-03])

# %%
model.intercept_
# Out:
# 55.99843051871995

# %%
y_pred =model.predict(X_test)

# %%
r2score = r2_score(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = mean_squared_error(y_test, y_pred, squared=False)
print('R2_score: ', r2score)
print('MAE: ', mae)
print('MSE: ', mse)
print('RMSE: ', rmse)
# Out:
# R2_score:  0.8841914157967063
# MAE:  1.9770870202711612
# MSE:  7.092041562405332
# RMSE:  2.663088725973157

# %%
import joblib
joblib.dump(model,'Nuovomodel.pkl')
# Out:
# ['Nuovomodel.pkl']

# %%
model_loaded = joblib.load('Nuovomodel.pkl')
model_loaded
# Out:
# LinearRegression()

# %%
print('coeficente:' , model_loaded.coef_)
# Out:
# coeficente: [-2.98104327e-02  8.69153644e-02  2.75531888e-02 -4.25947075e-05
#   1.38515742e-02 -6.39754943e-02  1.38793079e-02  1.09043445e-02
#  -4.31597801e-01 -2.86336016e-01  3.41159404e-03  2.41430940e+01
#  -2.57118503e-03]

# %%
print('interception:', model_loaded.intercept_)
# Out:
# interception: 55.99843051871995
